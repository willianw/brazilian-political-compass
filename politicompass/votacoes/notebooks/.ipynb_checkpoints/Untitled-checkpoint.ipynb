# %%
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import PIL
import glob
from datetime import datetime

# %%
cand = pd.read_csv('data/candidatos.csv')
votos = pd.read_csv('data/votos.csv')

# %%
hist = cand[['ano', 'candidato_id', 'partido']]

# %%
hist.duplicated().any()
# Out:
# False

# %%
votos['date'] = votos['date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))
votos['ano'] = votos['date'].apply(lambda x:x.year)

# %%
df = pd.merge(hist, votos, on=['candidato_id', 'ano'], how='inner')

# %%
plt.figure(figsize=(20,3))
df['partido'].value_counts().plot(kind="bar")

# %%
partido_cont = df['partido'].value_counts()
mfp = partido_cont[partido_cont > 20000].index.values.tolist()
df = df[df['partido'].isin(mfp)]

# %%
v = pd.pivot_table(df, values='voto', index=['candidato_id', 'partido'], columns='sessao_id', fill_value=0)

# %%
v
# Out:
# sessao_id             01/1991  011/2001  052/1999  071/98  08/99  09/99  \
# candidato_id partido
# 3151         DEM            0         0         0       0   0.00    0.0
# 3155         DEM            0         0         0       0   0.00    0.0
# 4927         DEM            0         0         0       0   0.00    0.0
# 4929         PSB            0         0         0       0   0.00    0.0
#              PT             0         0         0       0   0.00    0.0
# 4930         PTB            0         0         0       0   0.00    0.0
# 4931         PSDB           0         0         0       0   0.00    0.0
# 62881        PMDB           0         0         0       0   0.00    0.0
# 62926        PTB            0         0         0       0   0.00    0.0
# 64224        PFL            0         0         0       0   0.00    0.0
# 64960        PSB            0         0         0       0   0.00    0.0
# 65498        PSDB           1        -1         0       0   0.50    0.0
# 65511        PSB            0         0         0       0   0.00    0.0
# 65551        PDT            0         0         0       0   0.00    0.0
# 65904        PMDB           0        -1         0       0   0.75    0.0
# 65987        PMDB           0         0         0       0   0.00    0.0
# 66476        PDT            0         0         0       0   0.00    0.0
# 66490        PSDB           0         0         0       0   0.00    0.0
# 67105        PT             0         0         0       0   0.00    0.0
# 67138        PP             0         0         0       0   0.00    0.0
# 67836        PT             0         0         0       0   0.00    0.0
# 68676        PT             0         0         0       0   0.00    0.0
# 72553        PMDB           0         0         0       0   0.00    0.0
# 73416        PMDB           0         0         0       0   0.00    0.0
#              PSDB           0         0         0       0   0.00    0.0
# 73417        PSDB           0         0         0       0   0.00    0.0
# 73418        PMDB           0         0         0       0   0.00    0.0
# 73419        PPB            0         0         0       0   0.00    0.0
# 73420        PTB            1         0         0       0   0.75    0.0
# 73421        PSDB           0         0         0       0   0.75    0.0
# ...                       ...       ...       ...     ...    ...    ...
# 166401       PSDB           0         0         0       0   0.00    0.0
# 166402       PR             0         0         0       0   0.00    0.0
# 167493       PDT            0         0         0       0   0.00    0.0
# 167614       PSB            0         0         0       0   0.00    0.0
# 167617       PT             0         0         0       0   0.00    0.0
# 167707       PMDB           0         0         0       0   0.00    0.0
# 167722       PDT            0         0         0       0   0.00    0.0
# 168034       PSB            0         0         0       0   0.00    0.0
# 168447       PMDB           0         0         0       0   0.00    0.0
# 169553       PMDB           0         0         0       0   0.00    0.0
# 169711       PSDB           0         0         0       0   0.00    0.0
# 169712       PSB            0         0         0       0   0.00    0.0
# 170489       PDT            0         0         0       0   0.00    0.0
# 171617       PT             0         0         0       0   0.00    0.0
# 171618       DEM            0         0         0       0   0.00    0.0
# 171619       PT             0         0         0       0   0.00    0.0
# 171620       PP             0         0         0       0   0.00    0.0
# 171622       PR             0         0         0       0   0.00    0.0
# 171623       PMDB           0         0         0       0   0.00    0.0
# 172029       PT             0         0         0       0   0.00    0.0
# 172711       PSDB           0         0         0       0   0.00    0.0
# 173262       PT             0         0         0       0   0.00    0.0
# 173269       PMDB           0         0         0       0   0.00    0.0
# 173802       PR             0         0         0       0   0.00    0.0
# 174861       PMDB           0         0         0       0   0.00    0.0
# 175212       PT             0         0         0       0   0.00    0.0
# 175737       PT             0         0         0       0   0.00    0.0
# 176794       PT             0         0         0       0   0.00    0.0
# 177282       PDT            0         0         0       0   0.00    0.0
# 178387       PT             0         0         0       0   0.00    0.0
#
# sessao_id                 1/95     10/99  101/2003  102/95  ...  914/95  \
# candidato_id partido                                        ...
# 3151         DEM      0.000000  0.000000       0.0       0  ...       0
# 3155         DEM      0.000000  0.000000       0.0       0  ...       0
# 4927         DEM      0.000000  0.000000       0.0       0  ...       0
# 4929         PSB      0.000000  0.000000       0.0       0  ...       0
#              PT       0.000000  0.000000       0.0       0  ...       0
# 4930         PTB      0.000000  0.000000       0.0       0  ...       0
# 4931         PSDB     0.000000  0.000000       0.0       0  ...       0
# 62881        PMDB     0.000000  0.000000       0.0       0  ...       0
# 62926        PTB      0.000000  0.000000       0.0       0  ...       0
# 64224        PFL      0.000000  0.000000       1.0       0  ...       0
# 64960        PSB      0.000000  0.000000       1.0       0  ...       0
# 65498        PSDB     0.000000  1.000000       0.0       0  ...       0
# 65511        PSB      0.000000  0.000000       0.0       0  ...       0
# 65551        PDT      0.000000  0.000000      -1.0       0  ...       0
# 65904        PMDB     0.000000  0.333333       0.0       0  ...       0
# 65987        PMDB     0.000000  0.000000       1.0       0  ...       0
# 66476        PDT      0.000000  0.000000       0.0       0  ...       0
# 66490        PSDB     0.000000  0.000000       0.0       0  ...       0
# 67105        PT       0.222222  0.000000       0.0      -1  ...      -1
# 67138        PP       0.000000  0.000000       0.0       0  ...       0
# 67836        PT       0.111111  0.000000       0.0      -1  ...      -1
# 68676        PT       0.111111  0.000000       0.0      -1  ...       0
# 72553        PMDB     0.000000  0.000000       0.0       0  ...       0
# 73416        PMDB     0.000000  0.000000       0.0       0  ...       0
#              PSDB     0.000000  0.000000       0.0       0  ...       0
# 73417        PSDB     0.000000  0.000000       0.0       0  ...       0
# 73418        PMDB    -0.333333  0.000000       0.0       0  ...      -1
# 73419        PPB     -0.500000  0.000000       0.0       1  ...       1
# 73420        PTB     -0.250000  0.666667       1.0       1  ...      -1
# 73421        PSDB     0.000000  1.000000       0.0       0  ...       0
# ...                        ...       ...       ...     ...  ...     ...
# 166401       PSDB     0.000000  0.000000       0.0       0  ...       0
# 166402       PR       0.000000  0.000000       0.0       0  ...       0
# 167493       PDT      0.000000  0.000000       0.0       0  ...       0
# 167614       PSB      0.000000  0.000000       0.0       0  ...       0
# 167617       PT       0.000000  0.000000       0.0       0  ...       0
# 167707       PMDB     0.000000  0.000000       0.0       0  ...       0
# 167722       PDT      0.000000  0.000000       0.0       0  ...       0
# 168034       PSB      0.000000  0.000000       0.0       0  ...       0
# 168447       PMDB     0.000000  0.000000       0.0       0  ...       0
# 169553       PMDB     0.000000  0.000000       0.0       0  ...       0
# 169711       PSDB     0.000000  0.000000       0.0       0  ...       0
# 169712       PSB      0.000000  0.000000       0.0       0  ...       0
# 170489       PDT      0.000000  0.000000       0.0       0  ...       0
# 171617       PT       0.000000  0.000000       0.0       0  ...       0
# 171618       DEM      0.000000  0.000000       0.0       0  ...       0
# 171619       PT       0.000000  0.000000       0.0       0  ...       0
# 171620       PP       0.000000  0.000000       0.0       0  ...       0
# 171622       PR       0.000000  0.000000       0.0       0  ...       0
# 171623       PMDB     0.000000  0.000000       0.0       0  ...       0
# 172029       PT       0.000000  0.000000       0.0       0  ...       0
# 172711       PSDB     0.000000  0.000000       0.0       0  ...       0
# 173262       PT       0.000000  0.000000       0.0       0  ...       0
# 173269       PMDB     0.000000  0.000000       0.0       0  ...       0
# 173802       PR       0.000000  0.000000       0.0       0  ...       0
# 174861       PMDB     0.000000  0.000000       0.0       0  ...       0
# 175212       PT       0.000000  0.000000       0.0       0  ...       0
# 175737       PT       0.000000  0.000000       0.0       0  ...       0
# 176794       PT       0.000000  0.000000       0.0       0  ...       0
# 177282       PDT      0.000000  0.000000       0.0       0  ...       0
# 178387       PT       0.000000  0.000000       0.0       0  ...       0
#
# sessao_id             9261/2013  940/2007  9459/2014  95/96  9534/2014  \
# candidato_id partido
# 3151         DEM              1         0          1    0.0  -0.333333
# 3155         DEM              0         0          0    0.0   0.000000
# 4927         DEM              0         0          0    0.0   0.000000
# 4929         PSB              0         0          0    0.0   0.000000
#              PT               0         0          0    0.0   0.000000
# 4930         PTB              0         1          0    0.0   0.000000
# 4931         PSDB             1         0          1    0.0  -0.333333
# 62881        PMDB             1         0          1    0.0  -0.333333
# 62926        PTB              0         0          0    0.0   0.000000
# 64224        PFL              0         0          0    0.0   0.000000
# 64960        PSB              0         1          0    0.0   0.000000
# 65498        PSDB             0         0          0    0.0   0.000000
# 65511        PSB              0         0          0    0.0   0.000000
# 65551        PDT              0         0          0    0.0   0.000000
# 65904        PMDB             0         0          0    0.0   0.000000
# 65987        PMDB             0         0          0    0.0   0.000000
# 66476        PDT              0         0          0    0.0   0.000000
# 66490        PSDB             0         0          0    0.0   0.000000
# 67105        PT               0         0          0    0.0   0.000000
# 67138        PP               0         0          0    0.0   0.666667
# 67836        PT               0         0          0    0.0   0.000000
# 68676        PT               0         0          0    0.0   0.000000
# 72553        PMDB             0         0          0    0.0   0.000000
# 73416        PMDB             0         0          0    0.0   0.000000
#              PSDB             0         0          0    0.0   0.000000
# 73417        PSDB             0         0          0    0.0   0.000000
# 73418        PMDB             0         0          0    0.0   0.000000
# 73419        PPB              0         0          0    0.0   0.000000
# 73420        PTB              0         0          0    0.0   0.000000
# 73421        PSDB             0         0          0    0.0   0.000000
# ...                         ...       ...        ...    ...        ...
# 166401       PSDB             0         0          1    0.0  -0.333333
# 166402       PR               1         0          1    0.0   0.000000
# 167493       PDT              1         0          1    0.0  -0.333333
# 167614       PSB              1         0          1    0.0  -0.333333
# 167617       PT              -1         0          1    0.0   0.333333
# 167707       PMDB             0         0          0    0.0   0.000000
# 167722       PDT              1         0          1    0.0  -0.333333
# 168034       PSB              0         0          0    0.0   0.000000
# 168447       PMDB             1         0          1    0.0  -0.333333
# 169553       PMDB             0         0          0    0.0   0.000000
# 169711       PSDB             0         0          0    0.0   0.000000
# 169712       PSB              1         0          0    0.0  -0.333333
# 170489       PDT              0         0          0    0.0   0.000000
# 171617       PT               0         0          1    0.0   0.666667
# 171618       DEM              0         0          0    0.0  -0.333333
# 171619       PT               1         0          1    0.0  -0.333333
# 171620       PP               0         0          0    0.0  -0.333333
# 171622       PR              -1         0          1    0.0  -0.333333
# 171623       PMDB             0         0          1    0.0  -0.333333
# 172029       PT               1         0          1    0.0   0.000000
# 172711       PSDB             0         0          0    0.0   0.000000
# 173262       PT               0         0          0    0.0   0.000000
# 173269       PMDB             1         0          0    0.0   0.000000
# 173802       PR               0         0          0    0.0   0.000000
# 174861       PMDB             1         0          0    0.0   0.000000
# 175212       PT               1         0          0    0.0   0.000000
# 175737       PT               1         0          1    0.0   0.333333
# 176794       PT               0         0          0    0.0   0.000000
# 177282       PDT              0         0          0    0.0   0.000000
# 178387       PT               0         0          0    0.0   0.000000
#
# sessao_id             9556/2014     96/92  981/2008  998/2001
# candidato_id partido
# 3151         DEM              1  0.000000       1.0         0
# 3155         DEM              0  0.000000       0.0         0
# 4927         DEM              0  0.000000       0.5         0
# 4929         PSB              0  0.000000       0.0         0
#              PT               0  0.000000       0.5         0
# 4930         PTB              0  0.000000       0.5         0
# 4931         PSDB             1  0.000000       0.0         0
# 62881        PMDB             1  0.000000       0.0         0
# 62926        PTB              0  0.000000       0.0         0
# 64224        PFL              0  0.000000       0.0         0
# 64960        PSB              0  0.000000       1.0         0
# 65498        PSDB             0  0.012195       0.0         0
# 65511        PSB              0  0.000000       0.0         0
# 65551        PDT              0  0.000000       0.0         0
# 65904        PMDB             0  0.000000       0.0        -1
# 65987        PMDB             0  0.000000       0.0         0
# 66476        PDT              0  0.000000       0.0         0
# 66490        PSDB             0  0.000000       0.0         0
# 67105        PT               0  0.000000       0.0         0
# 67138        PP               0  0.000000       0.0         0
# 67836        PT               0  0.000000       0.0         0
# 68676        PT               0  0.000000       0.0         0
# 72553        PMDB             0  0.134146       0.0         0
# 73416        PMDB             0  0.000000       0.5         0
#              PSDB             0  0.000000       0.0         0
# 73417        PSDB             0  0.000000       0.0         0
# 73418        PMDB             0  0.000000       0.0         0
# 73419        PPB              0  0.000000       0.0         0
# 73420        PTB              0  0.097561       0.0        -1
# 73421        PSDB             0  0.134146       0.0        -1
# ...                         ...       ...       ...       ...
# 166401       PSDB             1  0.000000       0.0         0
# 166402       PR               1  0.000000       0.0         0
# 167493       PDT              0  0.000000       0.0         0
# 167614       PSB              1  0.000000       0.0         0
# 167617       PT               1  0.000000       0.0         0
# 167707       PMDB             0  0.000000       0.0         0
# 167722       PDT              1  0.000000       0.0         0
# 168034       PSB              0  0.000000       0.0         0
# 168447       PMDB             1  0.000000       0.0         0
# 169553       PMDB             0  0.000000       0.0         0
# 169711       PSDB             0  0.000000       0.0         0
# 169712       PSB              0  0.000000       0.0         0
# 170489       PDT              0  0.000000       0.0         0
# 171617       PT               1  0.000000       0.0         0
# 171618       DEM              1  0.000000       0.0         0
# 171619       PT               1  0.000000       0.0         0
# 171620       PP               1  0.000000       0.0         0
# 171622       PR               1  0.000000       0.0         0
# 171623       PMDB             1  0.000000       0.0         0
# 172029       PT               1  0.000000       0.0         0
# 172711       PSDB             0  0.000000       0.0         0
# 173262       PT               0  0.000000       0.0         0
# 173269       PMDB             0  0.000000       0.0         0
# 173802       PR               0  0.000000       0.0         0
# 174861       PMDB             1  0.000000       0.0         0
# 175212       PT               0  0.000000       0.0         0
# 175737       PT               1  0.000000       0.0         0
# 176794       PT               0  0.000000       0.0         0
# 177282       PDT              0  0.000000       0.0         0
# 178387       PT               0  0.000000       0.0         0
#
# [1679 rows x 659 columns]

# %%
part = v.reset_index().drop('candidato_id', axis=1).groupby('partido').mean()

# %%
x, y = PCA(2).fit_transform(part).T
fig, ax = plt.subplots(figsize=(20, 6))

def getImage(partido):
    p = partido.upper().replace(' ', '')
    path = glob.glob(f"../logos/{p}.*")[0]
    img = PIL.Image.open(path)
    img.thumbnail((50, 50))
    return OffsetImage(img)

sns.scatterplot(x, y, hue=part.index)
for x0, y0, path in zip(x, y, part.index.tolist()):
    ab = AnnotationBbox(getImage(path), (x0, y0), frameon=False)
    ax.add_artist(ab)

# %%
x, y = PCA(2).fit_transform(v).T

plt.figure(figsize=(20,10))
partido = v.index.get_level_values('partido')
sns.scatterplot(x, y, hue=partido)
